# %%
from sdv.demo import load_tabular_demo

data = load_tabular_demo('student_placements')

data.head()
# Out:
#    student_id gender  second_perc  high_perc high_spec  degree_perc  \
# 0       17264      M        67.00      91.00  Commerce        58.00
# 1       17265      M        79.33      78.33   Science        77.48
# 2       17266      M        65.00      68.00      Arts        64.00
# 3       17267      M        56.00      52.00   Science        52.00
# 4       17268      M        85.80      73.60  Commerce        73.30
#
#   degree_type  work_experience  experience_years  employability_perc mba_spec  \
# 0    Sci&Tech            False                 0                55.0   Mkt&HR
# 1    Sci&Tech             True                 1                86.5  Mkt&Fin
# 2   Comm&Mgmt            False                 0                75.0  Mkt&Fin
# 3    Sci&Tech            False                 0                66.0   Mkt&HR
# 4   Comm&Mgmt            False                 0                96.8  Mkt&Fin
#
#    mba_perc   salary  placed start_date   end_date duration
# ...

# %%
from sdv.tabular import GaussianCopula

model = GaussianCopula(anonymize_fields = {'high_perc':'high_perc'})
model.fit(data)
# Out:
# /home/sandeep/miniconda3/envs/sdv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:5001: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# /home/sandeep/miniconda3/envs/sdv/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2494: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# /home/sandeep/miniconda3/envs/sdv/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:621: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# /home/sandeep/miniconda3/envs/sdv/lib/python3.8/site-packages/scipy/optimize/minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# ...

# %%
new_data = model.sample(200)

# %% [markdown]
# model.sample is failing 'PandasArray' object has no attribute "_str_match"
#
# works if you install sdv via conda in a new environment (do not use pip)
#
#  conda install -c sdv-dev -c conda-forge sdv

# %%
new_data.head()
# Out:
#    student_id gender  second_perc  high_perc high_spec  degree_perc  \
# 0       17342      M    64.782236  57.309362   Science    58.869916
# 1       17474      F    42.578779  49.860810  Commerce    50.328570
# 2       17396      M    57.188675  78.259950  Commerce    65.051915
# 3       17369      M    77.675822  62.411265  Commerce    67.371653
# 4       17353      M    70.753411  66.194370  Commerce    77.873245
#
#   degree_type  work_experience  experience_years  employability_perc mba_spec  \
# 0    Sci&Tech            False                 1           87.569160   Mkt&HR
# 1   Comm&Mgmt            False                 0           85.648876   Mkt&HR
# 2   Comm&Mgmt            False                 1           67.371768   Mkt&HR
# 3   Comm&Mgmt            False                 1           57.042333   Mkt&HR
# 4   Comm&Mgmt            False                 1           57.413747   Mkt&HR
#
#     mba_perc        salary  placed start_date   end_date duration
# ...
