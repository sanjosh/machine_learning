# %%
from sdv.demo import load_tabular_demo

data = load_tabular_demo('student_placements')

data.head()
# Out:
#    student_id gender  second_perc  high_perc high_spec  degree_perc  \
# 0       17264      M        67.00      91.00  Commerce        58.00
# 1       17265      M        79.33      78.33   Science        77.48
# 2       17266      M        65.00      68.00      Arts        64.00
# 3       17267      M        56.00      52.00   Science        52.00
# 4       17268      M        85.80      73.60  Commerce        73.30
#
#   degree_type  work_experience  experience_years  employability_perc mba_spec  \
# 0    Sci&Tech            False                 0                55.0   Mkt&HR
# 1    Sci&Tech             True                 1                86.5  Mkt&Fin
# 2   Comm&Mgmt            False                 0                75.0  Mkt&Fin
# 3    Sci&Tech            False                 0                66.0   Mkt&HR
# 4   Comm&Mgmt            False                 0                96.8  Mkt&Fin
#
#    mba_perc   salary  placed start_date   end_date duration
# 0     58.80  27000.0    True 2020-07-23 2020-10-12      3.0
# 1     66.28  20000.0    True 2020-01-11 2020-04-09      3.0
# 2     57.80  25000.0    True 2020-01-26 2020-07-13      6.0
# 3     59.43      NaN   False        NaT        NaT      NaN
# 4     55.50  42500.0    True 2020-07-04 2020-09-27      3.0

# %%
regex = r'{}(#[0-9]+)?$'.format(re.escape(column_name))
columns = data.columns[data.columns.str.match(regex)]

# %%
from sdv.tabular import GaussianCopula

model = GaussianCopula()
model.fit(data)
# Out:
# /home/sandeep/miniconda3/envs/sklearn/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:4965: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# /home/sandeep/miniconda3/envs/sklearn/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# /home/sandeep/miniconda3/envs/sklearn/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:621: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# /home/sandeep/miniconda3/envs/sklearn/lib/python3.8/site-packages/scipy/optimize/minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# /home/sandeep/miniconda3/envs/sklearn/lib/python3.8/site-packages/scipy/optimize/minpack.py:175: RuntimeWarning: The number of calls to function has reached maxfev = 600.
#   warnings.warn(msg, RuntimeWarning)
# /home/sandeep/miniconda3/envs/sklearn/lib/python3.8/site-packages/copulas/univariate/truncated_gaussian.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   a = (self.min - loc) / scale
# /home/sandeep/miniconda3/envs/sklearn/lib/python3.8/site-packages/copulas/univariate/truncated_gaussian.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   b = (self.max - loc) / scale

# %%
new_data = model.sample(200)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a5ead0d38176> in <module>
# ----> 1 new_data = model.sample(200)
#
# ~/miniconda3/envs/sklearn/lib/python3.8/site-packages/sdv/tabular/base.py in sample(self, num_rows, max_retries)
#     151         num_to_sample = num_rows
#     152         sampled = self._sample(num_to_sample)
# --> 153         sampled = self._metadata.reverse_transform(sampled)
#     154         sampled = self._metadata.filter_valid(sampled)
#     155         num_valid = len(sampled)
#
# ~/miniconda3/envs/sklearn/lib/python3.8/site-packages/sdv/metadata/table.py in reverse_transform(self, data)
#     553             raise MetadataNotFittedError()
#     554
# --> 555         reversed_data = self._hyper_transformer.reverse_transform(data)
#     556
#     557         for constraint in self._constraints:
#
# ~/miniconda3/envs/sklearn/lib/python3.8/site-packages/rdt/hyper_transformer.py in reverse_transform(self, data)
#     261
#     262         for column_name, transformer in self._transformers.items():
# --> 263             columns = self._get_columns(data, column_name)
#     264             data[column_name] = transformer.reverse_transform(columns)
#     265
#
# ~/miniconda3/envs/sklearn/lib/python3.8/site-packages/rdt/hyper_transformer.py in _get_columns(data, column_name)
#     235         """
#     236         regex = r'{}(#[0-9]+)?$'.format(re.escape(column_name))
# --> 237         columns = data.columns[data.columns.str.match(regex)]
#     238         if columns.empty:
#     239             raise ValueError('No columns match_ {}'.format(column_name))
#
# ~/miniconda3/envs/sklearn/lib/python3.8/site-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#      99                 )
#     100                 raise TypeError(msg)
# --> 101             return func(self, *args, **kwargs)
#     102
#     103         wrapper.__name__ = func_name
#
# ~/miniconda3/envs/sklearn/lib/python3.8/site-packages/pandas/core/strings/accessor.py in match(self, pat, case, flags, na)
#    1141         extract : Extract matched groups.
#    1142         """
# -> 1143         result = self._array._str_match(pat, case=case, flags=flags, na=na)
#    1144         return self._wrap_result(result, fill_value=na, returns_string=False)
#    1145
#
# AttributeError: 'PandasArray' object has no attribute '_str_match'
